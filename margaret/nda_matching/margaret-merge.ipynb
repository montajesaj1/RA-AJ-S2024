# %%
import pandas as pd

# %%
inxight = pd.read_csv("3_inxight_data_final.csv")
inxight
# Out:
#               original_molecule            parsed_molecule          cas  \
# 0     1-2-PROPANEDIOL_DIACETATE  1,2 PROPANEDIOL DIACETATE     623-84-7
# 1                 1-HEXADECANOL              1 HEXADECANOL   36653-82-4
# 2                 1-OCTADECANOL              1 OCTADECANOL     112-92-5
# 3            2-OXOGLUTARIC_ACID         2 OXOGLUTARIC ACID     328-50-7
# 4                    2-PROPANOL                 2 PROPANOL      67-63-0
# ...                         ...                        ...          ...
# 2302    ZIRCONIUM_CYCLOSILICATE    ZIRCONIUM CYCLOSILICATE   17141-74-1
# 2303            ZOLEDRONIC_ACID            ZOLEDRONIC ACID  118072-93-8
# 2304               ZOLMITRIPTAN               ZOLMITRIPTAN  139264-17-8
# 2305                   ZOLPIDEM                   ZOLPIDEM   82626-48-0
# 2306                 ZONISAMIDE                 ZONISAMIDE   68291-97-4
#
#                              best_result_url  results  \
# ...

# %%
margaret = pd.read_csv('margaret_with_id.csv')
margaret.head()
# Out:
# /tmp/ipykernel_31960/3175694630.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   margaret = pd.read_csv('margaret_with_id.csv')
#                                       url  \
# 0  https://drugs.ncats.io/drug/L2B0WJF7ZY
# 1  https://drugs.ncats.io/drug/997WVV895X
# 2  https://drugs.ncats.io/drug/1EJ6Z6Q368
# 3  https://drugs.ncats.io/drug/8110R61I4U
# 4  https://drugs.ncats.io/drug/7V4A8U16MB
#
#                                               common       preferred  \
# 0  ['LACTITOL ANHYDROUS', 'LACTOBIOSIT', 'MIRUHEN...        LACTITOL
# 1  ['BHV-3000', 'RIMEGEPANT [INN]', 'RIMEGEPANT [...      RIMEGEPANT
# 2  ['PENTADECANEDIOIC ACID, 8-HYDROXY-2,2,14,14-T...  BEMPEDOIC ACID
# 3  ['AMISULPRIDE [EP]', 'AMISULPRIDE [WHO-DD]', '...     AMISULPRIDE
# 4      ['REMIMAZOLAM [INN]', 'REMIMAZOLAM [WHO-DD]']     REMIMAZOLAM
#
#                                         brand     inn     pubchem  who_atc  \
# ...

# %%
merged_cas = pd.merge(inxight, margaret, how='left', on='cas')
merged_cas
# Out:
#               original_molecule            parsed_molecule          cas  \
# 0     1-2-PROPANEDIOL_DIACETATE  1,2 PROPANEDIOL DIACETATE     623-84-7
# 1                 1-HEXADECANOL              1 HEXADECANOL   36653-82-4
# 2                 1-OCTADECANOL              1 OCTADECANOL     112-92-5
# 3            2-OXOGLUTARIC_ACID         2 OXOGLUTARIC ACID     328-50-7
# 4                    2-PROPANOL                 2 PROPANOL      67-63-0
# ...                         ...                        ...          ...
# 2505    ZIRCONIUM_CYCLOSILICATE    ZIRCONIUM CYCLOSILICATE   17141-74-1
# 2506            ZOLEDRONIC_ACID            ZOLEDRONIC ACID  118072-93-8
# 2507               ZOLMITRIPTAN               ZOLMITRIPTAN  139264-17-8
# 2508                   ZOLPIDEM                   ZOLPIDEM   82626-48-0
# 2509                 ZONISAMIDE                 ZONISAMIDE   68291-97-4
#
#                              best_result_url  results  \
# ...

# %%
merged_cas.to_csv('margaret_inxight_merged_id.csv')
