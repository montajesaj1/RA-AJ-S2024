# %%
import pandas as pd
data = pd.read_excel('5_cortellis_inxight_simple.xlsx')
data
# Out:
#                            Inxight Conditions  \
# 0                             Dry, itchy skin
# 1     Respiratory distress syndrome, neonatal
# 2                                     SUNBURN
# 3                                        Burn
# 4                              Kidney failure
# ...                                       ...
# 3331                      Disuse osteoporosis
# 3332                       Migraine with aura
# 3333                    Migraine without aura
# 3334                                 Insomnia
# 3335                                 Epilepsy
#
#                                       Cortellis Matches
# 0     [['Xerosis', 'Eczema', 'Atopic dermatitis'], [...
# 1                                                    []
# 2                     [['None'], ['None'], ['Sunburn']]
# 3                  [['Skin burns'], ['None'], ['None']]
# 4     [['End stage renal disease', 'Renal failure', ...
# ...                                                 ...
# ...

# %%
data['Inxight Conditions'] = data['Inxight Conditions'].str.lower()
conditions = data.drop_duplicates(subset='Inxight Conditions')

# %%
conditions
# Out:
#                            Inxight Conditions  \
# 0                             dry, itchy skin
# 1     respiratory distress syndrome, neonatal
# 2                                     sunburn
# 3                                        burn
# 4                              kidney failure
# ...                                       ...
# 3319                      severe chronic pain
# 3328                            hypercalcemia
# 3329     prostate cancer with bone metastasis
# 3330                     renal osteodystrophy
# 3331                      disuse osteoporosis
#
#                                       Cortellis Matches
# 0     [['Xerosis', 'Eczema', 'Atopic dermatitis'], [...
# 1                                                    []
# 2                     [['None'], ['None'], ['Sunburn']]
# 3                  [['Skin burns'], ['None'], ['None']]
# 4     [['End stage renal disease', 'Renal failure', ...
# ...                                                 ...
# ...

# %%
arr = conditions['Inxight Conditions'].to_list()
len(arr)
# Out:
# 1369
